# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# <b>Load Data</b>

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

df = pd.read_csv("../datasets/data_pre_processing.csv")
df.sample(5)
# Out:
#                               corpus_name  \
# 15131               measuring hate speech
# 61344  hate speech and offensive language
# 76534          twitter sentiment analysis
# 82893          twitter sentiment analysis
# 45058  hate speech and offensive language
#
#                                                                                                                                  raw_sentence  \
# 15131                                                                                                Niggas suck more dick then these bitches
# 61344                                                                                  These hoes are hilarious these days &#128514;&#128514;
# 76534        so much to smile about   #grad #selfie ð¸ððð i love these ladies to the moon and backâ¤ï¸ #bestassociatesever ð
# 82893                                                  be   feel #good about yourself try our #counselingwithdebbie &amp; reach your #goals
# 45058  @alexnolan1990 @claddos @takutaneka @regankelly91 ill give you a tip, beware of the ugly birds who hide behind massive lensed sunnies!
#
#                                         clean_sentence_training  \
# 15131                                    Niggas suck dick bitch
# 61344                                           These hilarious
# 76534  much smile grad selfie love lady moon bestassociatesever
# 82893                 feel good counselingwithdebbie reach goal
# 45058  give beware ugly bird hide behind massive lensed sunnies
#
#                    label  \
# 15131          non-risky
# 61344          non-risky
# 76534          non-risky
# 82893          non-risky
# 45058  potentially-risky
#
#                                              clean_sentence_EDA
# 15131                                    Niggas suck dick bitch
# 61344                                           These hilarious
# 76534  much smile grad selfie love lady moon bestassociatesever
# 82893                 feel good counselingwithdebbie reach goal
# 45058  give beware ugly bird hide behind massive lensed sunnies

# %%
df.shape
# Out:
# (93878, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93878 entries, 0 to 93877
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   corpus_name              93878 non-null  object
#  1   raw_sentence             93878 non-null  object
#  2   clean_sentence_training  93487 non-null  object
#  3   label                    93878 non-null  object
#  4   clean_sentence_EDA       93487 non-null  object
# dtypes: object(5)
# memory usage: 3.6+ MB

# %% [markdown]
# <b>Check Missing Value</b>

# %%
# percentage
((df.isna().sum()/df.shape[0])*100).round(2)
# Out:
# corpus_name                0.00
# raw_sentence               0.00
# clean_sentence_training    0.42
# label                      0.00
# clean_sentence_EDA         0.42
# dtype: float64

# %%
# total
df.isna().sum()
# Out:
# corpus_name                  0
# raw_sentence                 0
# clean_sentence_training    391
# label                        0
# clean_sentence_EDA         391
# dtype: int64

# %%
df.columns
# Out:
# Index(['corpus_name', 'raw_sentence', 'clean_sentence_training', 'label',
#        'clean_sentence_EDA'],
#       dtype='object')

# %%
df.dtypes
# Out:
# corpus_name                object
# raw_sentence               object
# clean_sentence_training    object
# label                      object
# clean_sentence_EDA         object
# dtype: object

# %% [markdown]
# <b>Number of Characters</b>

# %%
import matplotlib.pyplot as plt

fig,(ax1,ax2,ax3)=plt.subplots(1,3, figsize=(12,4))

dfca_len=df[df['label']=='risky']['clean_sentence_EDA'].str.len()
ax1.hist(dfca_len,color='steelblue')
ax1.set_title('Risky')

dfcb_len=df[df['label']=='potentially-risky']['clean_sentence_EDA'].str.len()
ax2.hist(dfcb_len,color='deepskyblue')
ax2.set_title('Potentially Risky')

dfcc_len=df[df['label']=='non-risky']['clean_sentence_EDA'].str.len()
ax3.hist(dfcc_len,color='lightskyblue')
ax3.set_title('Non Risky')

fig.suptitle('Characters in sentences')
plt.show()

# %% [markdown]
# <b>Number of Words</b>

# %%
fig,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(12,4))

dfwa_len=df[df['label']=='risky']['clean_sentence_EDA'].str.split().map(lambda x: len(x))
ax1.hist(dfwa_len,color='steelblue')
ax1.set_title('Risky')

dfwb_len=df[df['label']=='potentially-risky']['clean_sentence_EDA'].str.split().map(lambda x: len(x))
ax2.hist(dfwb_len,color='deepskyblue')
ax2.set_title('Potentially Risky')

# dfwc_len=df[df['label']=='non-risky']['clean_sentence_EDA'].str.split().map(lambda x: len(x))
# ax3.hist(dfwc_len,color='lightskyblue')
# ax3.set_title('Non Risky')

fig.suptitle('Words in sentences')
plt.show()

# %%
import seaborn as sns
import numpy as np

fig,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(12,4))

wordaa=df[df['label']=='risky']['clean_sentence_EDA'].str.split().apply(lambda x : [len(i) for i in x])
sns.distplot(wordaa.map(lambda x: np.mean(x)),ax=ax1,color='steelblue')
ax1.set_title('Risky')

wordab=df[df['label']=='potentially-risky']['clean_sentence_EDA'].str.split().apply(lambda x : [len(i) for i in x])
sns.distplot(wordab.map(lambda x: np.mean(x)),ax=ax2,color='deepskyblue')
ax2.set_title('Potentially Risky')

# wordac=df[df['label']=='non-risky']['clean_sentence_EDA'].str.split().apply(lambda x : [len(i) for i in x])
# sns.distplot(wordac.map(lambda x: np.mean(x)),ax=ax3,color='lightskyblue')
# ax.set_title('Non Risky')

fig.suptitle('Average word length in each sentence')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0.98, 'Average word length in each sentence')

# %% [markdown]
# <b>Analyzing Top Words</b>

# %%
from nltk.tokenize import word_tokenize
words = [word_tokenize(str(sentence)) for sentence in df['clean_sentence_EDA']]
word = [item for word in words for item in word]

# %%
from collections import Counter
most_common = Counter(word).most_common(25)
most_common
# Out:
# [('bitch', 13007),
#  ('like', 7777),
#  ('people', 5324),
#  ('love', 4139),
#  ('woman', 3921),
#  ('fuck', 3887),
#  ('pussy', 3488),
#  ('want', 3138),
#  ('shit', 3117),
#  ('nigga', 3109),
#  ('white', 3096),
#  ('know', 3023),
#  ('make', 2906),
#  ('would', 2887),
#  ('time', 2685),
#  ('need', 2676),
#  ('girl', 2603),
#  ('think', 2494),
#  ('life', 2493),
#  ('fucking', 2452),
#  ('back', 2236),
#  ('good', 2133),
#  ('This', 2057),
#  ('right', 1962),
#  ('even', 1955)]

# %%
#extract the word and the frequence count
words = [word for word, count in most_common]
frequency = [count for word, count in most_common]

#plot the 25 most common words 
plt.figure(figsize=(10,10))
plt.title("Most Common Words in the entire corpus")
plt.ylabel('Words')
plt.xlabel('Frequesncy')
plt.yticks()
sns.barplot(x = frequency, y = words);

# %%
df["label"].value_counts(normalize=True).to_frame().style.format('{:.6%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_9176a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9176a_level0_col0" class="col_heading level0 col0" >label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9176a_level0_row0" class="row_heading level0 row0" >non-risky</th>
#       <td id="T_9176a_row0_col0" class="data row0 col0" >72.053090%</td>
#     </tr>
#     <tr>
#       <th id="T_9176a_level0_row1" class="row_heading level0 row1" >potentially-risky</th>
#       <td id="T_9176a_row1_col0" class="data row1 col0" >23.000064%</td>
#     </tr>
#     <tr>
#       <th id="T_9176a_level0_row2" class="row_heading level0 row2" >risky</th>
#       <td id="T_9176a_row2_col0" class="data row2 col0" >4.946846%</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.title(" Analysis")
plt.ylabel("Label")
df["label"].value_counts().plot(kind="barh", color=['steelblue', 'deepskyblue', 'lightskyblue'])
plt.show()

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                min_font_size = 10).generate(clean_sentence_training)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/7c/j93bbf715k92mb331s_mlgsc0000gn/T/ipykernel_5398/1842304900.py in <module>
# ----> 1 wordcloud = WordCloud(width = 800, height = 800,
#       2                 background_color ='white',
#       3                 min_font_size = 10).generate(clean_sentence_training)
#       4
#       5 # plot the WordCloud image
#
# NameError: name 'WordCloud' is not defined
